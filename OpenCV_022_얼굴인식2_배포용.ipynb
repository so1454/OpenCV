# %% [markdown]
# <img src="./lecture_image/00_title.png">

# %% [markdown]
# <table border=1 width=100%>
#     <tr><td style="border: 1px solid black; width:600px; height:40px; text-align: center;"><font size=4 color=blue><b>[22차시] 학습목표</b></font></td></tr>
#     <tr><td style="border: 1px solid black; text-align: left;"><font size=3>
#
# ○ 딥러닝 기반 얼굴 추출 알고리즘에 대해 이해하고 사용할 수 있다.<br><br>
# ○ 딥러닝 기반 얼굴 인식 알고리즘에 대해 이해하고 사용할 수 있다.
#         </font></td></tr>
# </table>

# %% [markdown]
# # 딥러닝 기반 얼굴 추출
#
# ## SSD (Single Shot Dectector)
# - 2015년 발표
# - 다른 모델은 객체 감지를 위해 이미지를 2번 이상 반복하는 것에 반해 1번만으로 객체 감지
# - 백본 모델(피쳐 맵 추출기로 작동하는 일반적인 사전 학습된 이미지 분류 네트워크)과 SSD 헤드(두 개의 컨볼루션 레이어로 구성, 바운딩박스 출력)로 구성
#
# - 참고 : https://github.com/amdegroot/ssd.pytorch

# %% [markdown]
# ## MTCNN (Multi-Task Cascaded Convolutional Neural Network)
#
# - 2016년 4월 발표
# - 3단계의 CNN으로 구성
#   - P-Net (Proposed Net) : 얕은 CNN을 통해 후보 창을 신속하게 생성
#   - R-Net (Refine Net) : 더 복잡한 CNN을 통해 많은 수의 얼굴이 아닌 바운딩 박스를 제외하여 구체화
#   - O-Net (Output Net) : 강력한 CNN을 사용하여 결과를 구체화하고 다섯 개의 얼굴 랜드 마크 위치를 출력
#
# - 논문 : https://kpzhang93.github.io/MTCNN_face_detection_alignment/paper/spl.pdf
# - 참고 : https://github.com/ipazc/mtcnn
#
#
# <img src="./lecture_image/22_mtcnn.jpg" width="30%">

# %%
# !pip install mtcnn
# Out:
# Collecting mtcnn
#   Using cached mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
# Requirement already satisfied: opencv-python>=4.1.0 in d:\anaconda3\envs\yolov7\lib\site-packages (from mtcnn) (4.6.0.66)
# Requirement already satisfied: keras>=2.0.0 in d:\anaconda3\envs\yolov7\lib\site-packages (from mtcnn) (2.10.0)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\egeg\appdata\roaming\python\python39\site-packages (from opencv-python>=4.1.0->mtcnn) (1.22.4)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.1

# %%
# 코드작성
# Out:
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 6/6 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 109ms/step
# [{'box': [257, 315, 103, 140], 'confidence': 0.9999537467956543, 'keypoints': {'left_eye': (285, 371), 'right_eye': (332, 367), 'nose': (311, 402), 'mouth_left': (287, 417), 'mouth_right': (336, 413)}}, {'box': [136, 273, 119, 139], 'confidence': 0.9892764091491699, 'keypoints': {'left_eye': (182, 319), 'right_eye': (225, 342), 'nose': (194, 347), 'mouth_left': (159, 364), 'mouth_right': (200, 384)}}, {'box': [376, 307, 136, 135], 'confidence': 0.9875848293304443, 'keypoints': {'left_eye': (420, 384), 'right_eye': (460, 349), 'nose': (458, 386), 'mouth_left': (456, 421), 'mouth_right': (490, 393)}}, {'box': [205, 193, 124, 126], 'confidence': 0.9416548609733582, 'keypoints': {'left_eye': (247, 241), 'right_eye': (274, 250), 'nose': (252, 273), 'mouth_left': (242, 277), 'mouth_right': (263, 286)}}, {'box': [418, 8, 141, 160], 'confidence': 0.808786153793335, 'keypoints': {'left_eye': (494, 75), 'right_eye': (515, 95), 'nose': (493, 104), 'mouth_left': (469, 116), 'mouth_right': (484, 131)}}, {'box': [427, 168, 145, 142], 'confidence': 0.7850731015205383, 'keypoints': {'left_eye': (487, 243), 'right_eye': (519, 224), 'nose': (519, 260), 'mouth_left': (513, 274), 'mouth_right': (541, 257)}}, {'box': [258, 71, 97, 113], 'confidence': 0.7811532020568848, 'keypoints': {'left_eye': (284, 110), 'right_eye': (323, 110), 'nose': (304, 138), 'mouth_left': (293, 161), 'mouth_right': (327, 158)}}]
# (-0.5, 727.5, 500.5, -0.5)

# %% [markdown]
# ## DSFD (Dual Shot Face Dectector)
#
# - 2019년 4월 발표
# - 2개의 스트림 형태로 구성
# - 논문 : https://arxiv.org/abs/1810.10220
# - 참고 : https://github.com/yxlijun/DSFD.pytorch
# - face_detection 참고 : https://pypi.org/project/face-detection/
#
# <img src="./lecture_image/22_dsfd.png" width="50%">

# %%
# !pip install face_detection
# Out:
# Collecting face_detection
#   Downloading face_detection-0.2.2.tar.gz (20 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: torch>=1.6 in d:\anaconda3\envs\yolov7\lib\site-packages (from face_detection) (1.8.1+cu111)
# Requirement already satisfied: torchvision>=0.3.0 in d:\anaconda3\envs\yolov7\lib\site-packages (from face_detection) (0.9.1+cu111)
# Requirement already satisfied: numpy in c:\users\egeg\appdata\roaming\python\python39\site-packages (from face_detection) (1.22.4)
# Requirement already satisfied: typing-extensions in d:\anaconda3\envs\yolov7\lib\site-packages (from torch>=1.6->face_detection) (4.3.0)
# Requirement already satisfied: pillow>=4.1.1 in d:\anaconda3\envs\yolov7\lib\site-packages (from torchvision>=0.3.0->face_detection) (9.2.0)
# Building wheels for collected packages: face_detection
#   Building wheel for face_detection (setup.py): started
#   Building wheel for face_detection (setup.py): finished with status 'done'
#   Created wheel for face_detection: filename=face_detection-0.2.2-py3-none-any.whl size=25574 sha256=e3efae1020998db1d1e39232a47cdbef5af0956b61d7e2a9f015c2305314d235
#   Stored in directory: c:\users\egeg\appdata\local\pip\cache\wheels\1c\de\dd\656a84610209e1ca425274f89ab1eb413d2093d8288debb7bd
# Successfully built face_detection
# Installing collected packages: face_detection
# Successfully installed face_detection-0.2.2

# %%
# 코드작성
# Out:
# [[261.172      313.50623    359.957      459.81393      0.99998295]
#  [419.23294      4.4633055  548.50446    177.78714      0.999864  ]
#  [147.37997    278.8461     249.08821    404.28983      0.9998636 ]
#  [264.0376      38.837757   398.1815     196.0919       0.9998634 ]
#  [378.7288     315.15317    503.49966    438.39746      0.9998149 ]
#  [421.286      184.62158    575.17615    299.2767       0.9965061 ]
#  [187.3237     192.98473    333.93784    303.38504      0.9943211 ]]
# (-0.5, 727.5, 500.5, -0.5)

# %% [markdown]
# ## RetinaFace
#
# - 2019년 5월 발표
# - 성능이 매우 우수한 얼굴인식기 (mxnet 기반)
# - 참고 : https://github.com/serengil/retinaface

# %%
# !pip install retina-face
# Out:
# Collecting retina-face
#   Downloading retina_face-0.0.12-py3-none-any.whl (15 kB)
# Requirement already satisfied: tensorflow>=1.9.0 in d:\anaconda3\envs\yolov7\lib\site-packages (from retina-face) (2.10.0)
# Collecting gdown>=3.10.1
#   Downloading gdown-4.5.1.tar.gz (14 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.14.0 in c:\users\egeg\appdata\roaming\python\python39\site-packages (from retina-face) (1.22.4)
# Requirement already satisfied: opencv-python>=3.4.4 in d:\anaconda3\envs\yolov7\lib\site-packages (from retina-face) (4.6.0.66)
# Requirement already satisfied: Pillow>=5.2.0 in d:\anaconda3\envs\yolov7\lib\site-packages (from retina-face) (9.2.0)
# Requirement already satisfied: tqdm in d:\anaconda3\envs\yolov7\lib\site-packages (from gdown>=3.10.1->retina-face) (4.64.0)
# Requirement already satisfied: requests[socks] in d:\anaconda3\envs\yolov7\lib\site-packages (from gdown>=3.10.1->retina-face) (2.28.1)
# Collecting filelock
#   Downloading filelock-3.8.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda3\envs\yolov7\lib\site-packages (from gdown>=3.10.1->retina-face) (4.11.1)
# Requirement already satisfied: six in d:\anaconda3\envs\yolov7\lib\site-packages (from gdown>=3.10.1->retina-face) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorflow>=1.9.0->retina-face) (4.3.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorflow>=1.9.0->retina-face) (0.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorflow>=1.9.0->retina-face) (1.14.1)
# Requirement already satisfied: keras<2.11,>=2.10.0 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorflow>=1.9.0->retina-face) (2.10.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorflow>=1.9.0->retina-face) (1.1.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorflow>=1.9.0->retina-face) (3.19.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorflow>=1.9.0->retina-face) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorflow>=1.9.0->retina-face) (3.7.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorflow>=1.9.0->retina-face) (1.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorflow>=1.9.0->retina-face) (1.47.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorflow>=1.9.0->retina-face) (0.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorflow>=1.9.0->retina-face) (2.0.7)
# Requirement already satisfied: libclang>=13.0.0 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorflow>=1.9.0->retina-face) (14.0.6)
# Requirement already satisfied: absl-py>=1.0.0 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorflow>=1.9.0->retina-face) (1.2.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorflow>=1.9.0->retina-face) (2.10.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorflow>=1.9.0->retina-face) (2.10.0)
# Requirement already satisfied: packaging in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorflow>=1.9.0->retina-face) (21.3)
# Requirement already satisfied: astunparse>=1.6.0 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorflow>=1.9.0->retina-face) (1.6.3)
# Requirement already satisfied: setuptools in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorflow>=1.9.0->retina-face) (61.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorflow>=1.9.0->retina-face) (0.27.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\anaconda3\envs\yolov7\lib\site-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->retina-face) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->retina-face) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->retina-face) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->retina-face) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->retina-face) (2.2.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->retina-face) (2.10.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\anaconda3\envs\yolov7\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->retina-face) (1.8.1)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda3\envs\yolov7\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->retina-face) (2.3.2.post1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda3\envs\yolov7\lib\site-packages (from packaging->tensorflow>=1.9.0->retina-face) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda3\envs\yolov7\lib\site-packages (from requests[socks]->gdown>=3.10.1->retina-face) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\envs\yolov7\lib\site-packages (from requests[socks]->gdown>=3.10.1->retina-face) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\anaconda3\envs\yolov7\lib\site-packages (from requests[socks]->gdown>=3.10.1->retina-face) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\envs\yolov7\lib\site-packages (from requests[socks]->gdown>=3.10.1->retina-face) (2022.6.15)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: colorama in d:\anaconda3\envs\yolov7\lib\site-packages (from tqdm->gdown>=3.10.1->retina-face) (0.4.5)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anaconda3\envs\yolov7\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->retina-face) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\anaconda3\envs\yolov7\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->retina-face) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda3\envs\yolov7\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->retina-face) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\anaconda3\envs\yolov7\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->retina-face) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in d:\anaconda3\envs\yolov7\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->retina-face) (4.12.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\anaconda3\envs\yolov7\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->retina-face) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in d:\anaconda3\envs\yolov7\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->retina-face) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\anaconda3\envs\yolov7\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->retina-face) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\anaconda3\envs\yolov7\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->retina-face) (3.2.0)
# Building wheels for collected packages: gdown
#   Building wheel for gdown (pyproject.toml): started
#   Building wheel for gdown (pyproject.toml): finished with status 'done'
#   Created wheel for gdown: filename=gdown-4.5.1-py3-none-any.whl size=14933 sha256=799d1cb3b99b288170e8f1bc6235b52ebc387aac3f0f555f30c2f3992f9bfed7
#   Stored in directory: c:\users\egeg\appdata\local\pip\cache\wheels\b8\79\f0\b523d25d96b0bbb12bb024b97940d08c4fcd498a00070c8d82
# Successfully built gdown
# Installing collected packages: PySocks, filelock, gdown, retina-face
# Successfully installed PySocks-1.7.1 filelock-3.8.0 gdown-4.5.1 retina-face-0.0.12

# %%
# 코드작성
# Out:
# {'score': 0.9999904632568359, 'facial_area': [413, 178, 595, 289], 'landmarks': {'right_eye': [486.28766, 280.68268], 'left_eye': [479.18723, 207.33089], 'nose': [521.18427, 238.80844], 'mouth_right': [562.3892, 261.1716], 'mouth_left': [556.7553, 204.40172]}}

# %%
# 코드작성
# Out:
# (-0.5, 727.5, 500.5, -0.5)

# %%
# 코드작성

# %% [markdown]
# ## YuNet
#
# - 2021년 10월 발표
# - CNN기반 얼굴 탐지기로 가볍고 빠름 (모델이 MB 미만)
# - 백본으로 mobilenet을 채택하고 총 85,000 개의 매개 변수를 포함
# - 정면얼굴이 아닌 경우에도 잘 동작
# - 참고 : https://github.com/opencv/opencv_zoo/tree/master/models/face_detection_yunet
# - 모델 훈련 : https://github.com/ShiqiYu/libfacedetection.train

# %%
# 코드작성
# Out:
# [[261.80145   316.14447    99.25239   135.38      286.7425    371.74557
#   334.97137   370.2483    311.74387   399.29788   292.50052   418.92325
#   331.6144    417.65607     0.9321335]
#  [386.6331    327.06015   112.25399   110.74113   418.76468   398.43115
#   437.17676   364.28955   446.7252    394.054     464.2835    413.1299
#   481.78915   384.30157     0.9117041]]
# (-0.5, 727.5, 500.5, -0.5)

# %% [markdown]
# ## 얼굴인식

# %% [markdown]
# - 실시간 오픈 소스 얼굴인식 소프트웨어
#   - 딥 페이스 : https://github.com/serengil/deepface?ref=hackernoon.com
#     - FaceNet 및 InsightFace와 같은 다양한 얼굴 인식 방법을 지원
#     - Python 개발자라면 시작하기 쉽지만 다른 사람들이 통합하기 어려움
#   - CompareFace : https://github.com/exadel-inc/CompreFace
#     - REST API를 사용하면 사전 기계 학습 기술 없이도 시스템에 쉽게 통합 가능
#     - 확장 가능하므로 여러 비디오 스트림에서 얼굴을 동시에 인식 가능
#     - FaceNet과 InsightFace 선택 가능
#     - 현재 개발 중
#   - face_recognition : https://github.com/ageitgey/face_recognition?ref=hackernoon.com
#     - 인기있는 API이지만 큰 개선 사항이 없고 상당히 오래된 얼굴 인식 모델을 사용
#   - FaceNet : https://github.com/davidsandberg/facenet?ref=hackernoon.com
#     - 정확도가 매우 높은 API지만 개선이 없음
#   - InsightFace : https://github.com/deepinsight/insightface?ref=hackernoon.com
#     - 얼굴 감지를 위해 가장 최근의 정확한 얼굴 인식 방법 중 하나
#     - LetinaFace 및 SubCenter-ArcFace를 지원
#     - 사용하기 쉽지 않다는 단점
#   - InsightFace-REST : https://github.com/SthPhoenix/InsightFace-REST?ref=hackernoon.com
#     - 2021년부터 생성된 API로 인식속도 향상 버전
#     - 얼굴 임베딩만 제공하므로 분류기는 따로 만들어야 함
#
#
# - 참고 사이트
#   - https://sefiks.com/2020/06/03/mastering-face-recognition-with-ensemble-learning/

# %% [markdown]
# ### face recognition 기반 이미지 내 얼굴 인식

# %% [markdown]
# - face_recognition : 업데이터 중지, 오래된 모델
#   - https://wiserloner.tistory.com/1123

# %% [markdown]
# ### 딥페이스 기반 얼굴인식
#
# - 딥페이스
#   - 다양한 얼굴 모델 사용 사용 가능

# %%
# !pip install deepface
# Out:
# Collecting deepface
#   Downloading deepface-0.0.75-py3-none-any.whl (65 kB)
# Collecting mtcnn>=0.1.0
#   Using cached mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
# Requirement already satisfied: keras>=2.2.0 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from deepface) (2.4.3)
# Collecting retina-face>=0.0.1
#   Using cached retina_face-0.0.12-py3-none-any.whl (15 kB)
# Requirement already satisfied: opencv-python>=4.5.5.64 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from deepface) (4.6.0.66)
# Collecting pandas>=0.23.4
#   Using cached pandas-1.3.5-cp37-cp37m-win_amd64.whl (10.0 MB)
# Collecting fire>=0.4.0
#   Downloading fire-0.4.0.tar.gz (87 kB)
# Requirement already satisfied: Flask>=1.1.2 in d:\anaconda3\envs\opencv2\lib\site-packages (from deepface) (2.2.2)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from deepface) (1.19.3)
# Requirement already satisfied: Pillow>=5.2.0 in d:\anaconda3\envs\opencv2\lib\site-packages (from deepface) (9.2.0)
# Collecting tqdm>=4.30.0
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Collecting gdown>=3.10.1
#   Using cached gdown-4.5.1.tar.gz (14 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: tensorflow>=1.9.0 in d:\anaconda3\envs\opencv2\lib\site-packages (from deepface) (2.4.0)
# Requirement already satisfied: six in c:\users\egeg\appdata\roaming\python\python37\site-packages (from fire>=0.4.0->deepface) (1.15.0)
# Requirement already satisfied: termcolor in c:\users\egeg\appdata\roaming\python\python37\site-packages (from fire>=0.4.0->deepface) (1.1.0)
# Requirement already satisfied: click>=8.0 in d:\anaconda3\envs\opencv2\lib\site-packages (from Flask>=1.1.2->deepface) (8.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in d:\anaconda3\envs\opencv2\lib\site-packages (from Flask>=1.1.2->deepface) (2.1.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in d:\anaconda3\envs\opencv2\lib\site-packages (from Flask>=1.1.2->deepface) (4.11.3)
# Requirement already satisfied: Werkzeug>=2.2.2 in d:\anaconda3\envs\opencv2\lib\site-packages (from Flask>=1.1.2->deepface) (2.2.2)
# Requirement already satisfied: Jinja2>=3.0 in d:\anaconda3\envs\opencv2\lib\site-packages (from Flask>=1.1.2->deepface) (3.0.3)
# Requirement already satisfied: colorama in d:\anaconda3\envs\opencv2\lib\site-packages (from click>=8.0->Flask>=1.1.2->deepface) (0.4.4)
# Collecting filelock
#   Using cached filelock-3.8.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda3\envs\opencv2\lib\site-packages (from gdown>=3.10.1->deepface) (4.11.1)
# Requirement already satisfied: requests[socks] in d:\anaconda3\envs\opencv2\lib\site-packages (from gdown>=3.10.1->deepface) (2.28.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in d:\anaconda3\envs\opencv2\lib\site-packages (from importlib-metadata>=3.6.0->Flask>=1.1.2->deepface) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in d:\anaconda3\envs\opencv2\lib\site-packages (from importlib-metadata>=3.6.0->Flask>=1.1.2->deepface) (3.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda3\envs\opencv2\lib\site-packages (from Jinja2>=3.0->Flask>=1.1.2->deepface) (2.1.1)
# Requirement already satisfied: scipy>=0.14 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from keras>=2.2.0->deepface) (1.4.1)
# Requirement already satisfied: pyyaml in c:\users\egeg\appdata\roaming\python\python37\site-packages (from keras>=2.2.0->deepface) (6.0)
# Requirement already satisfied: h5py in c:\users\egeg\appdata\roaming\python\python37\site-packages (from keras>=2.2.0->deepface) (2.10.0)
# Requirement already satisfied: pytz>=2017.3 in d:\anaconda3\envs\opencv2\lib\site-packages (from pandas>=0.23.4->deepface) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in d:\anaconda3\envs\opencv2\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: gast==0.3.3 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from tensorflow>=1.9.0->deepface) (0.3.3)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from tensorflow>=1.9.0->deepface) (1.1.2)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from tensorflow>=1.9.0->deepface) (1.12.1)
# Requirement already satisfied: wheel~=0.35 in d:\anaconda3\envs\opencv2\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.37.1)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: tensorboard~=2.4 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from tensorflow>=1.9.0->deepface) (2.9.1)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0rc0 in d:\anaconda3\envs\opencv2\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.4.0)
# Requirement already satisfied: absl-py~=0.10 in d:\anaconda3\envs\opencv2\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.15.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from tensorflow>=1.9.0->deepface) (3.19.4)
# Requirement already satisfied: grpcio~=1.32.0 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from tensorflow>=1.9.0->deepface) (1.32.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from tensorflow>=1.9.0->deepface) (1.12)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (2.7.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (3.3.7)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (1.8.1)
# Requirement already satisfied: setuptools>=41.0.0 in d:\anaconda3\envs\opencv2\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (61.2.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from tensorboard~=2.4->tensorflow>=1.9.0->deepface) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda3\envs\opencv2\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\anaconda3\envs\opencv2\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\envs\opencv2\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\envs\opencv2\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2022.6.15)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=1.9.0->deepface) (3.2.0)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda3\envs\opencv2\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.3.1)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Building wheels for collected packages: fire, gdown
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115942 sha256=7a0ce1cfce5259a27d0fc618390559240beb7cd6695470587a89fc66de407968
#   Stored in directory: c:\users\egeg\appdata\local\pip\cache\wheels\8a\67\fb\2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
#   Building wheel for gdown (PEP 517): started
#   Building wheel for gdown (PEP 517): finished with status 'done'
#   Created wheel for gdown: filename=gdown-4.5.1-py3-none-any.whl size=14933 sha256=9e183c70fdc4e3e2db6bcf0a6e91d35f5e25bae394bc25a7203028ba640269aa
#   Stored in directory: c:\users\egeg\appdata\local\pip\cache\wheels\3d\ec\b0\a96d1d126183f98570a785e6bf8789fca559853a9260e928e1
# Successfully built fire gdown
# Installing collected packages: PySocks, tqdm, filelock, gdown, retina-face, pandas, mtcnn, fire, deepface
# Successfully installed PySocks-1.7.1 deepface-0.0.75 filelock-3.8.0 fire-0.4.0 gdown-4.5.1 mtcnn-0.1.1 pandas-1.3.5 retina-face-0.0.12 tqdm-4.64.1
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\egeg\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\egeg\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\egeg\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\egeg\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\egeg\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\egeg\appdata\roaming\python\python37\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# paddleocr 2.6.0.1 requires attrdict, which is not installed.
# paddleocr 2.6.0.1 requires cython, which is not installed.
# paddleocr 2.6.0.1 requires imgaug, which is not installed.
# paddleocr 2.6.0.1 requires lmdb, which is not installed.
# paddleocr 2.6.0.1 requires lxml, which is not installed.
# paddleocr 2.6.0.1 requires openpyxl, which is not installed.
# paddleocr 2.6.0.1 requires premailer, which is not installed.
# paddleocr 2.6.0.1 requires pyclipper, which is not installed.
# paddleocr 2.6.0.1 requires rapidfuzz, which is not installed.
# paddleocr 2.6.0.1 requires scikit-image, which is not installed.
# paddleocr 2.6.0.1 requires shapely, which is not installed.
# paddleocr 2.6.0.1 requires visualdl, which is not installed.
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\egeg\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\egeg\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\egeg\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\egeg\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\egeg\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\egeg\appdata\roaming\python\python37\site-packages)

# %%
# !pip install lightgbm

# %%
from deepface import DeepFace

# 사용할 모델 종류
# Ensemble : 여러개의 모델을 사용
models = ["VGG-Face", "Facenet", "Facenet512", "OpenFace", 
          "DeepFace", "ArcFace", "Dlib", "Ensemble"]

# 평가 방법
metrics = ["cosine", "euclidean", "euclidean_l2"]

# 검출 방법
backends = ['opencv', 'ssd', 'dlib', 'mtcnn', 'retinaface', 'mediapipe']

# %% [markdown]
# #### 얼굴 영역 검출

# %%
# 코드작성
# Out:
# (([], []), ([], []))

# %% [markdown]
# #### 얼굴인식을 위한 특징 데이터 추출

# %%
# 코드작성

# %% [markdown]
# #### 2개의 얼굴 비교하기

# %%
# 코드작성
# Out:
# Loading DeepFace: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 2006.84it/s]
# face-recognition-ensemble-model.txt will be downloaded...
# Downloading...
# From: https://raw.githubusercontent.com/serengil/deepface/master/deepface/models/face-recognition-ensemble-model.txt
# To: C:\Users\EGEG\.deepface\weights\face-recognition-ensemble-model.txt
# 87.1kB [00:00, 10.9MB/s]
# {'verified': True,
#  'score': 0.9952928659719859,
#  'distance': [0.09243905641399786,
#   0.34586506771327635,
#   0.4299745490467969,
#   0.2082852596594289,
#   7.963353519699468,
#   0.6454227446556695,
#   0.13394241206934032,
#   0.5175759114745204,
#   0.25558678229460363,
#   74.01462743533615,
#   0.7149640302764942],
#  'model': ['VGG-Face', 'Facenet', 'OpenFace', 'DeepFace'],
#  'similarity_metric': ['cosine', 'euclidean', 'euclidean_l2']}

# %% [markdown]
# #### 얼굴 DB에서 유사한 얼굴 검색하기

# %%
# 코드작성
# Out:
# WARNING: Representations for images in  ./images/face_info/  folder were previously stored in  representations_dlib.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  7  representations found in  representations_dlib.pkl
# find function lasts  1.6677672863006592  seconds
#                         identity  Dlib_cosine
# 0  ./images/face_info//Elon2.jpg     0.059925

# %% [markdown]
# #### 나이, 성별, 인종, 표정 분석하기

# %%
# 코드작성
# Out:
# Action: emotion: 100%|███████████████████████████████████████████████████████████████████| 4/4 [00:03<00:00,  1.27it/s]
# {'age': 34,
#  'region': {'x': 114, 'y': 102, 'w': 215, 'h': 280},
#  'gender': 'Man',
#  'race': {'asian': 17.659088969230652,
#   'indian': 3.215765953063965,
#   'black': 1.02080088108778,
#   'white': 35.07978022098541,
#   'middle eastern': 9.75087285041809,
#   'latino hispanic': 33.27369689941406},
#  'dominant_race': 'white',
#  'emotion': {'angry': 0.5979376735799118,
#   'disgust': 0.0008875995792275044,
#   'fear': 2.5076293949859974,
#   'happy': 38.88404601121223,
#   'sad': 43.261023954214096,
#   'surprise': 0.018498027577413027,
#   'neutral': 14.729977532027812},
#  'dominant_emotion': 'sad'}

# %% [markdown]
# #### 카메라 영상에서 얼굴 DB에 저장된 얼굴 검색

# %%
# 코드작성
# Out:
# Detector backend is  retinaface
# WARNING: There is no image in this path (  ./image/face_info/ ) . Face recognition will not be performed.
# Emotion model loaded
# Age model loaded
# Gender model loaded
# Facial attibute analysis models loaded in  0.0009970664978027344  seconds
# Finding embeddings: 0it [00:00, ?it/s]
# Embeddings found for given data set in  0.009879112243652344  seconds

# %% [markdown]
# <table border=1 width=100%>
#     <tr><td style="border: 1px solid black; width:600px; height:40px; text-align: center;"><font size=4 color=blue><b>[22차시] 정리하기</b></font></td></tr>
#     <tr><td style="border: 1px solid black; text-align: left;"><font size=3>○
#         </font></td></tr>
# </table>
